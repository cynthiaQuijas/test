# %% [markdown]
# <a href="https://colab.research.google.com/github/cynthiaQuijas/test/blob/main/M2Act3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Alphabet Ejercicio
# Cynthia Cristal Quijas Flores A01655996

# %% [markdown]
# ## Librerías

# %%
# Librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  
import seaborn as sns 
import pandas_datareader as pdr 
import datetime

# %% [markdown]
# ## Base de datos

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('/content/gdrive/MyDrive/alphabet_stock_data.csv')

# %% [markdown]
# ## Ejercicio:
#
# Seleccionar dos fechas y graficar su evolución

# %%
df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# 1  2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2  2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3  2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4  2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
#
#      Adj Close   Volume
# 0  1105.619995  2343100
# 1  1120.839966  1964900
# 2  1097.880005  2313400
# 3  1186.920044  2664700
# 4  1186.510010  2387300

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       127 non-null    datetime64[ns]
#  1   Open       127 non-null    float64
#  2   High       127 non-null    float64
#  3   Low        127 non-null    float64
#  4   Close      127 non-null    float64
#  5   Adj Close  127 non-null    float64
#  6   Volume     127 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 7.1 KB

# %%
# Connvertir tipo de dato a formato fecha
df['Date'] = pd.to_datetime(df.Date, format = '%Y-%m-%d')
df
# Out:
#           Date         Open         High          Low        Close  \
# 0   2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# 1   2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2   2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3   2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4   2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
# ..         ...          ...          ...          ...          ...
# 122 2020-09-24  1411.030029  1443.708984  1409.849976  1428.290039
# 123 2020-09-25  1432.630005  1450.000000  1413.339966  1444.959961
# 124 2020-09-28  1474.209961  1476.800049  1449.301025  1464.520020
# 125 2020-09-29  1470.390015  1476.662964  1458.805054  1469.329956
# 126 2020-09-30  1466.800049  1489.750000  1459.880005  1469.599976
#
#        Adj Close   Volume
# 0    1105.619995  2343100
# 1    1120.839966  1964900
# 2    1097.880005  2313400
# 3    1186.920044  2664700
# ...

# %%
# Seleccionar columnas de fecha y close
#Se crea un nuevo dataframe con las columnas seleccionadas 
df2=df[['Date', 'Close']]
df2
# Out:
#           Date        Close
# 0   2020-04-01  1105.619995
# 1   2020-04-02  1120.839966
# 2   2020-04-03  1097.880005
# 3   2020-04-06  1186.920044
# 4   2020-04-07  1186.510010
# ..         ...          ...
# 122 2020-09-24  1428.290039
# 123 2020-09-25  1444.959961
# 124 2020-09-28  1464.520020
# 125 2020-09-29  1469.329956
# 126 2020-09-30  1469.599976
#
# [127 rows x 2 columns]

# %%
df3 = df2[(df2.Date>'2020-04-07') & (df2.Date<'2020-08-30')]

# %%
import matplotlib.pyplot as plt       ## wonderful library for data plotting
fig = plt.figure(figsize=(18,6))      ## To get a figure with proper structure

## Tiempo en x
## Close

# %%
fig, ax = plt.subplots()
ax.plot(df3.Date, df3.Close)
plt.title('Alphabet \n Cynthia Quijas')
plt.show()
